# %%
import pandas as pd

movies = pd.read_csv("movies.csv")

movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Film               77 non-null     object
#  1   Genre              77 non-null     object
#  2   Lead Studio        77 non-null     object
#  3   Audience score %   77 non-null     int64
#  4   Profitability      77 non-null     float64
#  5   Rotten Tomatoes %  77 non-null     int64
#  6   Worldwide Gross    77 non-null     object
#  7   Year               77 non-null     int64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 4.9+ KB

# %%
movies
# Out:
#                                   Film    Genre            Lead Studio  \
# 0           Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                      Youth in Revolt   Comedy  The Weinstein Company
# 2   You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                         When in Rome   Comedy                 Disney
# 4                What Happens in Vegas   Comedy                    Fox
# ..                                 ...      ...                    ...
# 72                 Across the Universe  romance            Independent
# 73                       A Serious Man    Drama              Universal
# 74                  A Dangerous Method    Drama            Independent
# 75                          27 Dresses   Comedy                    Fox
# 76                (500) Days of Summer   comedy                    Fox
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# ...

# %%
movies.Genre.unique()
# Out:
# array(['Romance', 'Comedy', 'Drama', 'Animation', 'Fantasy', 'Romence',
#        'Comdy', 'Action', 'romance', 'comedy'], dtype=object)

# %%
grp_genre = movies.groupby("Genre")

genre_count = []

for grp, grp_info in grp_genre:
    cat_dict = {}
    grp_gen = grp_genre.get_group(grp)

    for index,row in grp_gen.iterrows(): # to read the data inside those row and column
        if row["Genre"] not in cat_dict.keys():
            cat_dict[row["Genre"]] = [row["Film"]]
            
        else:
            if row["Film"] not in cat_dict.values():
                cat_dict[row["Genre"]].append(row["Film"])
    genre_count.append(cat_dict)


genre_count
# Out:
# [{'Action': ['Killers']},
#  {'Animation': ['WALL-E',
#    'Tangled',
#    'Gnomeo and Juliet',
#    'Gnomeo and Juliet']},
#  {'Comdy': ['Made of Honor']},
#  {'Comedy': ['Youth in Revolt',
#    'You Will Meet a Tall Dark Stranger',
#    'When in Rome',
#    'What Happens in Vegas',
#    "Valentine's Day",
#    'The Ugly Truth',
#    'The Proposal',
#    'The Invention of Lying',
#    'The Heartbreak Kid',
#    'The Back-up Plan',
#    "She's Out of My League",
#    'Sex and the City Two',
#    'Sex and the City 2',
#    'Sex and the City',
#    'Penelope',
#    'Over Her Dead Body',
#    'Our Family Wedding',
#    'No Reservations',
#    "Nick and Norah's Infinite Playlist",
#    'Miss Pettigrew Lives for a Day',
#    'Marley and Me',
#    'Mamma Mia!',
#    'Mamma Mia!',
#    'Love & Other Drugs',
#    'Life as We Know It',
#    'License to Wed',
#    'Letters to Juliet',
#    'Leap Year',
#    'Knocked Up',
#    'Just Wright',
#    "It's Complicated",
# ...

# %%
for row in genre_count:
    for  key,value in row.items():
        count = 0
        if isinstance(value, list): # To check whether the value is list form.
            for v in value:
                count +=1
            row[key] = count 
genre_count
# Out:
# [{'Action': 1},
#  {'Animation': 4},
#  {'Comdy': 1},
#  {'Comedy': 41},
#  {'Drama': 13},
#  {'Fantasy': 1},
#  {'Romance': 13},
#  {'Romence': 1},
#  {'comedy': 1},
#  {'romance': 1}]

# %%
print(movies["Audience score %"])
# Out:
# 0     70
# 1     52
# 2     35
# 3     44
# 4     72
#       ..
# 72    84
# 73    64
# 74    89
# 75    71
# 76    81
# Name: Audience score %, Length: 77, dtype: int64

# %%
grp_genre = movies.groupby("Genre")

audience_score = []

for grp, grp_info in grp_genre:
    cat_dict = {}
    grp_gen = grp_genre.get_group(grp)

    for index,row in grp_gen.iterrows(): # to read the data inside those row and column
        if row["Genre"] not in cat_dict.keys():
            cat_dict[row["Genre"]] = [row["Audience score %"]]
            
        else:
            if row["Audience score %"] not in cat_dict.values():
                cat_dict[row["Genre"]].append(row["Audience score %"])
    audience_score.append(cat_dict)


audience_score
# Out:
# [{'Action': [45]},
#  {'Animation': [89, 88, 52, 52]},
#  {'Comdy': [61]},
#  {'Comedy': [52,
#    35,
#    44,
#    72,
#    54,
#    68,
#    74,
#    47,
#    41,
#    47,
#    60,
#    49,
#    49,
#    81,
#    74,
#    47,
#    49,
#    64,
#    67,
#    70,
#    77,
#    76,
#    76,
#    55,
#    62,
#    55,
#    62,
#    49,
#    83,
#    58,
#    63,
#    57,
#    76,
#    60,
#    61,
#    56,
#    47,
#    52,
#    80,
#    80,
#    71]},
#  {'Drama': [72, 78, 65, 68, 70, 61, 66, 84, 40, 51, 66, 64, 89]},
#  {'Fantasy': [81]},
#  {'Romance': [70, 67, 53, 47, 68, 82, 48, 82, 54, 48, 70, 50, 77]},
#  {'Romence': [84]},
#  {'comedy': [81]},
#  {'romance': [84]}]

# %%
for row in audience_score:
    for  key,value in row.items():
        average = 0 
        if isinstance(value, list): # To check whether the value is list form.
            average = round(sum(value) / len(value),2)
            row[key] = average
            
audience_score
# Out:
# [{'Action': 45.0},
#  {'Animation': 70.25},
#  {'Comdy': 61.0},
#  {'Comedy': 60.98},
#  {'Drama': 67.23},
#  {'Fantasy': 81.0},
#  {'Romance': 62.77},
#  {'Romence': 84.0},
#  {'comedy': 81.0},
#  {'romance': 84.0}]
